# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
dfhouse=pd.read_csv(r"C:\Users\91918\OneDrive\Desktop\ML datasets\Melbourne_housing_FULL.csv")

# %%
dfhouse
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
dfhouse.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
cols_to_use = ['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname',
               'Propertycount', 'Distance', 'CouncilArea', 'Bedroom2',
               'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Price']

# %%
cols_to_use
# Out:
# ['Suburb',
#  'Rooms',
#  'Type',
#  'Method',
#  'SellerG',
#  'Regionname',
#  'Propertycount',
#  'Distance',
#  'CouncilArea',
#  'Bedroom2',
#  'Bathroom',
#  'Car',
#  'Landsize',
#  'BuildingArea',
#  'Price']

# %%
dfhouse[cols_to_use]
# Out:
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 0      Abbotsford      2    h     SS         Jellis  Northern Metropolitan
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 3      Abbotsford      3    u     VB         Rounds  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
# ...

# %%
df = dfhouse[cols_to_use]

# %%
df
# Out:
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 0      Abbotsford      2    h     SS         Jellis  Northern Metropolitan
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 3      Abbotsford      3    u     VB         Rounds  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
# ...

# %% [markdown]
# NaNs

# %%
dfhouse.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.columns
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname',
#        'Propertycount', 'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'Price'],
#       dtype='object')

# %%
dfhouse.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df[['Propertycount', 'Distance','Bedroom2', 'Bathroom', 'Car']]
# Out:
#        Propertycount  Distance  Bedroom2  Bathroom  Car
# 0             4019.0       2.5       2.0       1.0  1.0
# 1             4019.0       2.5       2.0       1.0  1.0
# 2             4019.0       2.5       2.0       1.0  0.0
# 3             4019.0       2.5       3.0       2.0  1.0
# 4             4019.0       2.5       3.0       2.0  0.0
# ...              ...       ...       ...       ...  ...
# 34852         6543.0       6.3       4.0       1.0  3.0
# 34853         6543.0       6.3       2.0       2.0  1.0
# 34854         6543.0       6.3       2.0       1.0  2.0
# 34855         6543.0       6.3       NaN       NaN  NaN
# 34856         6543.0       6.3       2.0       1.0  0.0
#
# [34857 rows x 5 columns]

# %%
df[['Propertycount', 'Distance','Bedroom2', 'Bathroom', 'Car']].isna().sum()
# Out:
# Propertycount       3
# Distance            1
# Bedroom2         8217
# Bathroom         8226
# Car              8728
# dtype: int64

# %%
df[['Propertycount', 'Distance','Bedroom2', 'Bathroom', 'Car']].fillna(0)
# Out:
#        Propertycount  Distance  Bedroom2  Bathroom  Car
# 0             4019.0       2.5       2.0       1.0  1.0
# 1             4019.0       2.5       2.0       1.0  1.0
# 2             4019.0       2.5       2.0       1.0  0.0
# 3             4019.0       2.5       3.0       2.0  1.0
# 4             4019.0       2.5       3.0       2.0  0.0
# ...              ...       ...       ...       ...  ...
# 34852         6543.0       6.3       4.0       1.0  3.0
# 34853         6543.0       6.3       2.0       2.0  1.0
# 34854         6543.0       6.3       2.0       1.0  2.0
# 34855         6543.0       6.3       0.0       0.0  0.0
# 34856         6543.0       6.3       2.0       1.0  0.0
#
# [34857 rows x 5 columns]

# %%
df[['Propertycount', 'Distance','Bedroom2', 'Bathroom', 'Car']].fillna(0).isna().sum()
# Out:
# Propertycount    0
# Distance         0
# Bedroom2         0
# Bathroom         0
# Car              0
# dtype: int64

# %%
df[['Propertycount', 'Distance','Bedroom2', 'Bathroom', 'Car']].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
df[['Propertycount', 'Distance','Bedroom2', 'Bathroom', 'Car']] = df[['Propertycount', 'Distance','Bedroom2', 'Bathroom', 'Car']].fillna(0)

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        0
# Distance             0
# CouncilArea          3
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
df["Landsize"].isna().sum()
# Out:
# np.int64(11810)

# %%
df["Landsize"].mean()
# Out:
# np.float64(593.598993361392)

# %%
df["Landsize"].fillna(df["Landsize"].mean().round(2))
# Out:
# 0        126.0
# 1        202.0
# 2        156.0
# 3          0.0
# 4        134.0
#          ...
# 34852    593.0
# 34853     98.0
# 34854    220.0
# 34855    593.6
# 34856    250.0
# Name: Landsize, Length: 34857, dtype: float64

# %%
dfhouse[['Propertycount','Distance','Bedroom2','Bathroom','Car']]=dfhouse[['Propertycount','Distance','Bedroom2','Bathroom','Car']].fillna(0)

# %%
df["Landsize"].fillna(df["Landsize"].mean().round(2)).isna().sum()
# Out:
# np.int64(0)

# %%
df["Landsize"].fillna(df["Landsize"].mean().round(2), inplace = True)

# %%
dfhouse["BuildingArea"].mean().round(2)
# Out:
# np.float64(160.26)

# %%
dfhouse["BuildingArea"].fillna(dfhouse["BuildingArea"].mean().round(2),inplace=True)

# %%
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        0
# Distance             0
# CouncilArea          3
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize             0
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
df["BuildingArea"]
# Out:
# 0          NaN
# 1          NaN
# 2         79.0
# 3          NaN
# 4        150.0
#          ...
# 34852      NaN
# 34853    104.0
# 34854    120.0
# 34855      NaN
# 34856    103.0
# Name: BuildingArea, Length: 34857, dtype: float64

# %%
df["BuildingArea"].mean().round(2)
# Out:
# np.float64(160.26)

# %%
df["BuildingArea"].fillna(df["BuildingArea"].mean().round(2))
# Out:
# 0        160.26
# 1        160.26
# 2         79.00
# 3        160.26
# 4        150.00
#           ...
# 34852    160.26
# 34853    104.00
# 34854    120.00
# 34855    160.26
# 34856    103.00
# Name: BuildingArea, Length: 34857, dtype: float64

# %%
df["BuildingArea"].fillna(df["BuildingArea"].mean().round(2)).isna().sum()
# Out:
# np.int64(0)

# %%
df["BuildingArea"].fillna(df["BuildingArea"].mean().round(2), inplace = True)

# %%
dfhouse.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             0
# Postcode             1
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea         0
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        0
# dtype: int64

# %%
df.dropna()
# Out:
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# 5      Abbotsford      3    h     PI         Biggin  Northern Metropolitan
# 6      Abbotsford      4    h     VB         Nelson  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
# ...

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %% [markdown]
# ### Encoding

# %%
df.dtypes
# Out:
# Suburb            object
# Rooms              int64
# Type              object
# Method            object
# SellerG           object
# Regionname        object
# Propertycount    float64
# Distance         float64
# CouncilArea       object
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# Price            float64
# dtype: object

# %%
df["Suburb"].unique()
# Out:
# array(['Abbotsford', 'Airport West', 'Albert Park', 'Alphington',
#        'Altona', 'Altona North', 'Armadale', 'Ascot Vale', 'Ashburton',
#        'Ashwood', 'Avondale Heights', 'Balaclava', 'Balwyn',
#        'Balwyn North', 'Bentleigh', 'Bentleigh East', 'Box Hill',
#        'Braybrook', 'Brighton', 'Brighton East', 'Brunswick',
#        'Brunswick West', 'Bulleen', 'Burwood', 'Camberwell', 'Canterbury',
#        'Carlton North', 'Carnegie', 'Caulfield', 'Caulfield North',
#        'Caulfield South', 'Chadstone', 'Clifton Hill', 'Coburg',
#        'Coburg North', 'Collingwood', 'Doncaster', 'Eaglemont',
#        'Elsternwick', 'Elwood', 'Essendon', 'Essendon North', 'Fairfield',
#        'Fitzroy', 'Fitzroy North', 'Flemington', 'Footscray', 'Glen Iris',
#        'Glenroy', 'Gowanbrae', 'Hadfield', 'Hampton', 'Hampton East',
#        'Hawthorn', 'Heidelberg Heights', 'Heidelberg West', 'Hughesdale',
#        'Ivanhoe', 'Kealba', 'Keilor East', 'Kensington', 'Kew',
# ...

# %%
df["Suburb"].nunique()
# Out:
# 344

# %%
df.dtypes
# Out:
# Suburb            object
# Rooms              int64
# Type              object
# Method            object
# SellerG           object
# Regionname        object
# Propertycount    float64
# Distance         float64
# CouncilArea       object
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# Price            float64
# dtype: object

# %%
df["Type"].unique()
# Out:
# array(['h', 't', 'u'], dtype=object)

# %%
df["Method"].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
df["SellerG"].unique()
# Out:
# array(['Biggin', 'Nelson', 'Jellis', 'Dingle', 'Purplebricks', 'Greg',
#        'LITTLE', 'Collins', 'Kay', 'Beller', 'Marshall', 'hockingstuart',
#        'Brad', 'Maddison', 'Barry', 'Airport', 'Considine', 'Rendina',
#        'Ray', 'Propertyau', 'McDonald', 'Frank', 'Prof.', 'Harcourts',
#        'Thomson', 'Buxton', 'RT', "Sotheby's", 'Cayzer', 'Chisholm',
#        'Brace', 'Miles', 'Holland', 'McGrath', 'Love', 'Thomas', 'Barlow',
#        'Sweeney', 'Village', 'Jas', 'Williams', 'Gunn&Co', 'Burnham',
#        'Compton', 'FN', 'Hunter', 'Raine&Horne', 'Noel', 'Hodges', 'Gary',
#        'Fletchers', 'Woodards', 'Raine', 'Alexkarbon', 'Walshe', 'Weda',
#        'Stockdale', 'Tim', 'AIME', 'Moonee', 'HAR', 'Edward', 'Philip',
#        'RW', 'North', 'MICM', 'Ascend', 'Christopher', 'Morrison',
#        'Mandy', 'R&H', 'Fletchers/One', 'Lindellas', 'Appleby', 'Assisi',
#        'One', 'Owen', 'Parkes', 'C21', "O'Brien", 'Bayside', 'Paul',
# ...

# %%
df["SellerG"].nunique()
# Out:
# 349

# %%
df["Regionname"].unique()
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Eastern Victoria',
#        'Northern Victoria', 'Western Victoria'], dtype=object)

# %%
df["CouncilArea"].unique()
# Out:
# array(['Yarra City Council', 'Moonee Valley City Council',
#        'Port Phillip City Council', 'Darebin City Council',
#        'Hobsons Bay City Council', 'Stonnington City Council',
#        'Boroondara City Council', 'Monash City Council',
#        'Glen Eira City Council', 'Whitehorse City Council',
#        'Maribyrnong City Council', 'Bayside City Council',
#        'Moreland City Council', 'Manningham City Council',
#        'Melbourne City Council', 'Banyule City Council',
#        'Brimbank City Council', 'Kingston City Council',
#        'Hume City Council', 'Knox City Council', 'Maroondah City Council',
#        'Casey City Council', 'Melton City Council',
#        'Greater Dandenong City Council', 'Nillumbik Shire Council',
#        'Whittlesea City Council', 'Frankston City Council',
#        'Macedon Ranges Shire Council', 'Yarra Ranges Shire Council',
#        'Wyndham City Council', 'Cardinia Shire Council',
# ...

# %%
pd.get_dummies(df, drop_first= True).replace([True, False], [1, 0])
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1          2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5          3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6          4         4019.0       2.5       3.0       1.0  2.0     120.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 34852      4         6543.0       6.3       4.0       1.0  3.0     593.0
# 34853      2         6543.0       6.3       2.0       2.0  1.0      98.0
# 34854      2         6543.0       6.3       2.0       1.0  2.0     220.0
# 34855      3         6543.0       6.3       0.0       0.0  0.0     593.6
# 34856      2         6543.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea      Price  Suburb_Aberfeldie  ...  \
# ...

# %%
df = pd.get_dummies(df, drop_first= True).replace([True, False], [1, 0])

# %%
df
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1          2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5          3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6          4         4019.0       2.5       3.0       1.0  2.0     120.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 34852      4         6543.0       6.3       4.0       1.0  3.0     593.0
# 34853      2         6543.0       6.3       2.0       2.0  1.0      98.0
# 34854      2         6543.0       6.3       2.0       1.0  2.0     220.0
# 34855      3         6543.0       6.3       0.0       0.0  0.0     593.6
# 34856      2         6543.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea      Price  Suburb_Aberfeldie  ...  \
# ...

# %%
df.drop("Price", axis = 1)
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1          2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5          3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6          4         4019.0       2.5       3.0       1.0  2.0     120.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 34852      4         6543.0       6.3       4.0       1.0  3.0     593.0
# 34853      2         6543.0       6.3       2.0       2.0  1.0      98.0
# 34854      2         6543.0       6.3       2.0       1.0  2.0     220.0
# 34855      3         6543.0       6.3       0.0       0.0  0.0     593.6
# 34856      2         6543.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# ...

# %%
X = df.drop("Price", axis = 1)

# %%
X
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1          2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5          3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6          4         4019.0       2.5       3.0       1.0  2.0     120.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 34852      4         6543.0       6.3       4.0       1.0  3.0     593.0
# 34853      2         6543.0       6.3       2.0       2.0  1.0      98.0
# 34854      2         6543.0       6.3       2.0       1.0  2.0     220.0
# 34855      3         6543.0       6.3       0.0       0.0  0.0     593.6
# 34856      2         6543.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# ...

# %%
y = df["Price"]

# %%
y
# Out:
# 1        1480000.0
# 2        1035000.0
# 4        1465000.0
# 5         850000.0
# 6        1600000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 27244, dtype: float64

# %%
X.shape
# Out:
# (27244, 744)

# %%
y.shape
# Out:
# (27244,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X.shape
# Out:
# (27244, 744)

# %%
X_train.shape
# Out:
# (21795, 744)

# %%
X_test.shape
# Out:
# (5449, 744)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model = LinearRegression()

# %%
lr_model
# Out:
# LinearRegression()

# %%
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr_model.score(X_test, y_test)
# Out:
# 0.6646254207935209

# %%
lr_model.score(X_train, y_train)
# Out:
# 0.6821250916864039

# %% [markdown]
# ### Ridge and Lasso

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge()

# %%
ridge_model
# Out:
# Ridge()

# %%
ridge_model.fit(X_train, y_train)

# %%
ridge_model.score(X_test, y_test)
# Out:
# 0.6877750229540011

# %%
ridge_model.score(X_train, y_train)
# Out:
# 0.6756717737545151

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import Lasso

# %%
lasso_model = Lasso()

# %%
lasso_model
# Out:
# Lasso()

# %%
lasso_model.fit(X_train, y_train)

# %%
lasso_model.score(X_test, y_test)
